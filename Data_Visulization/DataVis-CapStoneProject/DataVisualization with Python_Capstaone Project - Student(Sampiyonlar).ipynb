# %% [markdown]
# ![yaz%C4%B1.png](attachment:yaz%C4%B1.png)

# %% [markdown]
# <div class="alert alert-block alert-info alert">
#
# # <span style=" color:red">WELCOME!
#
# Welcome to "Bike Demand Visualization Project" which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.</span>

# %% [markdown]
# <div class="alert alert-block alert-success ">
#
# ## <span style=" color:red">Determines
#
# Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# "weather_code" category description:
#
# - 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# - 2 = scattered clouds / few clouds
# - 3 = Broken clouds
# - 4 = Cloudy
# - 7 = Rain/ light Rain shower/ Light rain
# - 10 = rain with thunderstorm
# - 26 = snowfall
# - 94 = Freezing Fog
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc. Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.
#
# # <span style=" color:red">Tasks
# </span>

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">1. Import Libraries
# </span>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">2. Read Dataset
# </span>

# %%
df = pd.read_csv('store_sharing.csv')

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">3. Check missing values and if there are any dublicate rows or not.
# </span>

# %%
df.isnull().any()
# Out:
# timestamp       False
# cnt             False
# t1              False
# t2              False
# hum             False
# wind_speed      False
# weather_code    False
# is_holiday      False
# is_weekend      False
# season          False
# dtype: bool

# %%
df.duplicated().value_counts()
# Out:
# False    17414
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">4. Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)
# </span>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
fig, ax = plt.subplots(2, 2, figsize=(25, 15))

sns.histplot(data=df, 
             x=df.season, 
             hue=df.weather_code,
             palette='plasma',
             ax=ax[0, 0])



sns.histplot(data=df,
             x=df.is_holiday,
             bins=2,
             ax=ax[0, 1])

sns.histplot(data=df,
             x=df.is_weekend,
             bins=2,
             ax=ax[1, 0])

sns.histplot(data=df,
            x=df.weather_code,
             ax=ax[1, 1])

plt.show()

# %% [markdown]
# # weather_code
# sns.countplot(x='weather_code',data=df)
#
# 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# 2 = scattered clouds / few clouds
# 3 = Broken clouds
# 4 = Cloudy
# 7 = Rain/ light Rain shower/ Light rain
# 10 = rain with thunderstorm
# 26 = snowfall
# 94 = Freezing Fog

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">5. Look at the data type of each variable, transform timestamp in type, and set it as index.
# </span>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df.timestamp = df.timestamp.astype(dtype='datetime64')

df.set_index(df.timestamp, drop=True, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17414 entries, 2015-01-04 00:00:00 to 2017-01-03 23:00:00
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  datetime64[ns]
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: datetime64[ns](1), float64(8), int64(1)
# memory usage: 1.5 MB

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">6. Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)
# </span>

# %% [markdown]
# ![Screenshot%202021-10-27%20164721.png](attachment:Screenshot%202021-10-27%20164721.png)

# %%
df.head()
# Out:
#                               timestamp  cnt   t1   t2    hum  wind_speed  \
# timestamp
# 2015-01-04 00:00:00 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0
# 2015-01-04 01:00:00 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0
# 2015-01-04 02:00:00 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0
# 2015-01-04 03:00:00 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0
# 2015-01-04 04:00:00 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5
#
#                      weather_code  is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00           3.0         0.0         1.0     3.0
# 2015-01-04 01:00:00           1.0         0.0         1.0     3.0
# 2015-01-04 02:00:00           1.0         0.0         1.0     3.0
# 2015-01-04 03:00:00           1.0         0.0         1.0     3.0
# 2015-01-04 04:00:00           1.0         0.0         1.0     3.0

# %%
df["day_of_the_week"]= df.index.day_of_week

df["day_of_the_month"] = df.index.strftime("%d")

df["hour"] = df.index.hour

df["month"] = df.index.month

df["year"] = df.index.year

season_mapping = {0 : "Spring",
                  1 : "Summer",
                  2 : 'Fall',
                  3 : 'Winter'}

df.season = df.season.map(season_mapping)

# %%
df.head()
# Out:
#                               timestamp  cnt   t1   t2    hum  wind_speed  \
# timestamp
# 2015-01-04 00:00:00 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0
# 2015-01-04 01:00:00 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0
# 2015-01-04 02:00:00 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0
# 2015-01-04 03:00:00 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0
# 2015-01-04 04:00:00 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5
#
#                      weather_code  is_holiday  is_weekend  season  \
# timestamp
# 2015-01-04 00:00:00           3.0         0.0         1.0  Winter
# 2015-01-04 01:00:00           1.0         0.0         1.0  Winter
# 2015-01-04 02:00:00           1.0         0.0         1.0  Winter
# 2015-01-04 03:00:00           1.0         0.0         1.0  Winter
# 2015-01-04 04:00:00           1.0         0.0         1.0  Winter
#
#                      day_of_the_week day_of_the_month  hour  month  year
# timestamp
# 2015-01-04 00:00:00                6               04     0      1  2015
# 2015-01-04 01:00:00                6               04     1      1  2015
# 2015-01-04 02:00:00                6               04     2      1  2015
# 2015-01-04 03:00:00                6               04     3      1  2015
# 2015-01-04 04:00:00                6               04     4      1  2015

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">7. Visualize the correlation with a heatmap
# </span>

# %%
plt.figure(figsize=(15, 10))

sns_heatmap = sns.heatmap(df.corr(),
                          annot=True,)

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">8. Visualize the correlation of the target variable and the other features with barplot
# </span>

# %%
df.corr().cnt.index
# Out:
# Index(['cnt', 't1', 't2', 'hum', 'wind_speed', 'weather_code', 'is_holiday',
#        'is_weekend', 'day_of_the_week', 'hour', 'month', 'year'],
#       dtype='object')

# %%
plt.figure(figsize=(20, 10))

plt.bar(df.corr().cnt.index,
        df.corr().cnt)

plt.show()

# %%
plt.figure(figsize=(15, 10))

cnt_corr_sns_bar_plot = sns.barplot(x=df.corr().cnt.index,
                                    y=df.corr().cnt)

# %% [markdown]
# ![Screenshot%202021-10-27%20170237.png](attachment:Screenshot%202021-10-27%20170237.png)

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">9. Plot bike shares over time use lineplot.
# </span>

# %%
plt.figure(figsize=(15, 10))

bikeshares_overtime = sns.lineplot(x=df.index,
                                   y=df.cnt)

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">10. Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot).
# </span>

# %%
plt.figure(figsize=(15, 10))

bikeshares_overtime = sns.lineplot(x=df.index.month,
                                   y=df.cnt)

# %%
plt.figure(figsize=(15, 10))

bikeshares_overtime = sns.lineplot(x=df.index.year,
                                   y=df.cnt)

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">11. Plot bike shares by hours on (holidays, weekend, season).
# </span>

# %%
plt.figure(figsize=(15, 10))

bikeshares_overtime = sns.lineplot(x=df.index.hour,
                                   y=df.cnt,
                                   hue=df.season)

# %%
plt.figure(figsize=(15, 10))

bikeshares_overtime = sns.barplot(x=df[df.is_weekend == 1].index.hour,
                                   y=df[df.is_weekend == 1].cnt,)

# %%
plt.figure(figsize=(15, 10))

bikeshares_overtime = sns.barplot(x=df[df.is_holiday == 1].index.hour,
                                   y=df[df.is_holiday == 1].cnt)

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 12. Plot bike shares by day of week.
#
# - You may want to see whether it is a holiday or not
# </span>

# %%
plt.figure(figsize=(15, 10))

bikeshares_overtime = sns.barplot(x=df.day_of_the_week,
                                   y=df.cnt,
                                   hue=df.is_holiday,)

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 13. Plot bike shares by day of month
# </span>

# %%
plt.figure(figsize=(15, 10))

bikeshares_overtime = sns.barplot(x=df.day_of_the_month,
                                   y=df.cnt)

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 14. Plot bike shares by year
#
# - Plot bike shares on holidays by seasons
# </span>

# %%
plt.figure(figsize=(15, 10))

bikeshares_overtime = sns.barplot(x=df.year,
                                   y=df.cnt,)

# %%
df[df.is_holiday == 1].season
# Out:
# timestamp
# 2015-04-03 00:00:00    Spring
# 2015-04-03 01:00:00    Spring
# 2015-04-03 02:00:00    Spring
# 2015-04-03 03:00:00    Spring
# 2015-04-03 04:00:00    Spring
#                         ...
# 2017-01-02 19:00:00    Winter
# 2017-01-02 20:00:00    Winter
# 2017-01-02 21:00:00    Winter
# 2017-01-02 22:00:00    Winter
# 2017-01-02 23:00:00    Winter
# Name: season, Length: 384, dtype: object

# %%
plt.figure(figsize=(15, 10))

bikeshares_overtime = sns.barplot(x=df[df.is_holiday == 1].season,
                                   y=df[df.is_holiday == 1].cnt)

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">15. Visualize the distribution of bike shares by weekday/weekend with piechart and barplot
# </span>

# %%
plt.figure(figsize=(15, 10))

bikeshares_overtime = sns.barplot(x=df.is_weekend,
                                   y=df.cnt,)

# %%
plt.figure(figsize=(15, 10))

bikeshares_overtime = sns.barplot(x=df.day_of_the_week,
                                   y=df.cnt,
                                   hue=df.is_weekend,)

# %%
plt.figure(figsize=(15, 10))

plt.pie(x=df.is_weekend.value_counts(),
       labels=["Weekdays", "Weekend"],
       autopct = "%.2f",
       explode=[0.05, 0],
       shadow=True,
       textprops={'fontsize': 20})

plt.show()

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">16. Plot the distribution of weather code by seasons
# </span>

# %%
plt.figure(figsize=(15, 10))

bikeshares_overtime = sns.barplot(x=df.season,
                                   y=df.weather_code)

# %%
df.weather_code.value_counts()
# Out:
# 1.0     6150
# 2.0     4034
# 3.0     3551
# 7.0     2141
# 4.0     1464
# 26.0      60
# 10.0      14
# Name: weather_code, dtype: int64

# %%
df.weather_code_mapped = df.weather_code.map({
    1:'Clear',
    2:'Few clouds',
    3:'Broken clouds',
    4:'Cloudy',
    7:'Light Rain shower',
    10:'Thunderstorm',
    26:'Snowfall',
    94:'Freezing Fog'
})
# Out:
# C:\Users\kerem\AppData\Local\Temp\ipykernel_13960\3235785585.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.weather_code_mapped = df.weather_code.map({

# %%
plt.figure(figsize=(20, 10))

sns.histplot(binwidth=0.5, x=df.season, hue=df.weather_code_mapped, data=df, stat="count", multiple="stack")

plt.show()

# %%
sns.barplot()

# %% [markdown]
# <div class="alert alert-info alert-info ">
#
# # <span style=" color:red">Conclusions
#
#
#
#
# </span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <span style=" color:red">Thanks for Attending!..
#
#
# </span>

# %% [markdown]
# ![yaz%C4%B1.webp](attachment:yaz%C4%B1.webp)
